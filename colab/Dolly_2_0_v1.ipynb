# %% [markdown]
# <a href="https://colab.research.google.com/github/MIDORIBIN/Dolly/blob/main/colab/Dolly_2_0_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate>=0.12.0 transformers[torch]==4.25.1

# %%
# !nvidia-smi
# Out:
# Thu Apr 13 15:18:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0    34W /  70W |   6831MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-2-8b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto")

# %%
# %%time
generate_text("Explain to me the difference between nuclear fission and fusion.")
# Out:
# CPU times: user 17.1 s, sys: 103 ms, total: 17.2 s
# Wall time: 25.7 s
# 'Nuclear fission, which is what happens in a commercial reactor, is caused when extremely high-energy atomic nuclei hit one another with enough force to split the atom.  Nuclear fusion, which occurs in a star, is caused when two or more atoms collide so hard that they fuse together and form a larger atom, and in so doing, create nearly as much energy as was put in when the fusion started.'

# %%
# %%time
generate_text("核分裂と核融合の違いについて説明してください。")
# Out:
# CPU times: user 1min 6s, sys: 0 ns, total: 1min 6s
# Wall time: 1min 6s
# '核分裂と核融合は同じですが、核融合の違いについてです。\n\n核融合の過程では、核分裂を起こした生命体に対してエネルギーを奪うことなく一方的に切断できるため、そして長期的に生存することができます。一方で、核融合した生命体には、異なる遺伝子のため違い、異なるバランスシートで環境に反応するため異なる生物種の性質が形作られていくため、残存することができません。'

# %%
# %%time
generate_text("日本の観光地を教えてください。")
# Out:
# CPU times: user 1min 1s, sys: 0 ns, total: 1min 1s
# Wall time: 1min 2s
# '歩き回れることができるような天然氷の処理 Facility\n園芸活動と遊んだりすまして遊んだりできるようなスポーツトラック Travel Bus\n火ennis で安定したかったら Resort Hotel with Fire Ring\n中高年層をターゲットにしてくれる商業施設を打ち出す Magazine 商材\n天然氷に溶けてけいらめく Rental Ice Cream Van\n日本を訪れる度に彼らのイラストをいただく日本のポップカルチャー ＆ 芸術表舞台 Sendou Kougei'
